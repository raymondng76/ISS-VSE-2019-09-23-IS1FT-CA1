# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import keras
from keras.models import Model
from keras.layers import Conv2D, Input, BatchNormalization, LeakyReLU, ZeroPadding2D, UpSampling2D, AveragePooling2D
from keras.layers.merge import add, concatenate

# %% [markdown]
# ### Create YoloV3 Model

# %%
def createYoloLyr(inputs, convLyrs, skip=True):
    '''Create a single YOLO layer'''
    x = inputs
    loopCounter = 0
    for convLyr in convLyrs:
        if loopCounter == (len(convLyrs)-2) and skip:
            skip_connection = x
        loopCounter += 1
        if convLyr['strides'] > 1: 
            x = ZeroPadding2D(((1,0),(1,0)), name='zeropad_'+str(convLyr['lyrName']))(x)
        x = Conv2D(filters=convLyr['filters'], 
                   kernel_size=convLyr['kernel_size'], 
                   strides=convLyr['strides'], 
                   padding='valid' if convLyr['strides']> 1 else 'same',  
                   use_bias=False if convLyr['bnorm'] else True, 
                   name='conc2d_'+str(convLyr['lyrName']))(x)
        if convLyr['bnorm']:
            x = BatchNormalization(epsilon=0.001, name='bnorm_idx_'+str(convLyr['lyrName']))(x)
        if convLyr['leakyRelu']:
            x = LeakyReLU(alpha=0.1, name='leakyrelu_idx_'+str(convLyr['lyrName']))(x)
    return add([skip_connection, x]) if skip else x

# %%
def createYoloBlk1(inputs):
    '''Create initial blocks'''
    x = createYoloLyr(inputs, [
        {'filters': 32, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 0},
        {'filters': 64, 'kernel_size': 3, 'strides': 2, 'bnorm': True, 'leakyRelu': True, 'lyrName': 1},
        {'filters': 32, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 2},
        {'filters': 64, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 3},
    ])
    x = createYoloLyr(x, [
        {'filters': 128, 'kernel_size': 3, 'strides': 2, 'bnorm': True, 'leakyRelu': True, 'lyrName': 5}, # Index jumped to 5 from 3 because of additional add layer
        {'filters': 64, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 6},
        {'filters': 128, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 7},
    ])
    x = createYoloLyr(x, [
        {'filters': 64, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 9},
        {'filters': 128, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 10},
    ])
    return x

# %%
def createYoloBlk2(inputs): # Block for small objects detection
    '''Create block for small objects detection'''
    x = createYoloLyr(inputs, [
        {'filters': 256, 'kernel_size': 3, 'strides': 2, 'bnorm': True, 'leakyRelu': True, 'lyrName': 12},
        {'filters': 128, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 13},
        {'filters': 256, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 14},
    ])
    for idx in range(7):
        x = createYoloLyr(x, [
            {'filters': 128, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 15+idx*3}, # Index * 3 is because there are 2 conv2D layer + 1 add layer
            {'filters': 256, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 16+idx*3},
        ])
    return x

# %%
def createYoloBlk3(inputs): # Block for medium objects detection    
    '''Create block for medium objects detection'''
    x = createYoloLyr(inputs, [
        {'filters': 512, 'kernel_size': 3, 'strides': 2, 'bnorm': True, 'leakyRelu': True, 'lyrName': 37},
        {'filters': 256, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 38},
        {'filters': 512, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 39},
    ])
    for idx in range(7):
        x = createYoloLyr(x, [
            {'filters': 256, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 41+idx*3},
            {'filters': 512, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 42+idx*3},
        ])
    return x

# %%
def createYoloBlk4(inputs):
    '''Create block for big objects detection'''
    x = createYoloLyr(inputs, [
        {'filters': 1024, 'kernel_size': 3, 'strides': 2, 'bnorm': True, 'leakyRelu': True, 'lyrName': 62},
        {'filters': 512, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 63},
        {'filters': 1024, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 64},
    ])
    for idx in range(7):
        x = createYoloLyr(x, [
            {'filters': 512, 'kernel_size': 1, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 66+idx*3},
            {'filters': 1024, 'kernel_size': 3, 'strides': 1, 'bnorm': True, 'leakyRelu': True, 'lyrName': 67+idx*3},
        ])
    return x

# %%
def build_YoloV3_Model():
    '''Build full YoloV3 model'''
    # Input Layer
    input_img = Input(shape=(None, None, 3))
    x = createYoloBlk1(input_img)
    x = createYoloBlk2(x)
    x = createYoloBlk3(x)
    x = createYoloBlk4(x)
    x = AvgP
    return Model(input_img, x)

# %%
model = build_YoloV3_Model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           (None, None, None, 3 0
# __________________________________________________________________________________________________
# conc2d_0 (Conv2D)               (None, None, None, 3 864         input_20[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_0 (BatchNormalization (None, None, None, 3 128         conc2d_0[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_0 (LeakyReLU)     (None, None, None, 3 0           bnorm_idx_0[0][0]
# __________________________________________________________________________________________________
# zeropad_1 (ZeroPadding2D)       (None, None, None, 3 0           leakyrelu_idx_0[0][0]
# __________________________________________________________________________________________________
# conc2d_1 (Conv2D)               (None, None, None, 6 18432       zeropad_1[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_1 (BatchNormalization (None, None, None, 6 256         conc2d_1[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_1 (LeakyReLU)     (None, None, None, 6 0           bnorm_idx_1[0][0]
# __________________________________________________________________________________________________
# conc2d_2 (Conv2D)               (None, None, None, 3 2048        leakyrelu_idx_1[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_2 (BatchNormalization (None, None, None, 3 128         conc2d_2[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_2 (LeakyReLU)     (None, None, None, 3 0           bnorm_idx_2[0][0]
# __________________________________________________________________________________________________
# conc2d_3 (Conv2D)               (None, None, None, 6 18432       leakyrelu_idx_2[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_3 (BatchNormalization (None, None, None, 6 256         conc2d_3[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_3 (LeakyReLU)     (None, None, None, 6 0           bnorm_idx_3[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, None, None, 6 0           leakyrelu_idx_1[0][0]
#                                                                  leakyrelu_idx_3[0][0]
# __________________________________________________________________________________________________
# zeropad_5 (ZeroPadding2D)       (None, None, None, 6 0           add_80[0][0]
# __________________________________________________________________________________________________
# conc2d_5 (Conv2D)               (None, None, None, 1 73728       zeropad_5[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_5 (BatchNormalization (None, None, None, 1 512         conc2d_5[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_5 (LeakyReLU)     (None, None, None, 1 0           bnorm_idx_5[0][0]
# __________________________________________________________________________________________________
# conc2d_6 (Conv2D)               (None, None, None, 6 8192        leakyrelu_idx_5[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_6 (BatchNormalization (None, None, None, 6 256         conc2d_6[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_6 (LeakyReLU)     (None, None, None, 6 0           bnorm_idx_6[0][0]
# __________________________________________________________________________________________________
# conc2d_7 (Conv2D)               (None, None, None, 1 73728       leakyrelu_idx_6[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_7 (BatchNormalization (None, None, None, 1 512         conc2d_7[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_7 (LeakyReLU)     (None, None, None, 1 0           bnorm_idx_7[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, None, None, 1 0           leakyrelu_idx_5[0][0]
#                                                                  leakyrelu_idx_7[0][0]
# __________________________________________________________________________________________________
# conc2d_9 (Conv2D)               (None, None, None, 6 8192        add_81[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_9 (BatchNormalization (None, None, None, 6 256         conc2d_9[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_9 (LeakyReLU)     (None, None, None, 6 0           bnorm_idx_9[0][0]
# __________________________________________________________________________________________________
# conc2d_10 (Conv2D)              (None, None, None, 1 73728       leakyrelu_idx_9[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_10 (BatchNormalizatio (None, None, None, 1 512         conc2d_10[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_10 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_10[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, None, None, 1 0           add_81[0][0]
#                                                                  leakyrelu_idx_10[0][0]
# __________________________________________________________________________________________________
# zeropad_12 (ZeroPadding2D)      (None, None, None, 1 0           add_82[0][0]
# __________________________________________________________________________________________________
# conc2d_12 (Conv2D)              (None, None, None, 2 294912      zeropad_12[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_12 (BatchNormalizatio (None, None, None, 2 1024        conc2d_12[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_12 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_12[0][0]
# __________________________________________________________________________________________________
# conc2d_13 (Conv2D)              (None, None, None, 1 32768       leakyrelu_idx_12[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_13 (BatchNormalizatio (None, None, None, 1 512         conc2d_13[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_13 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_13[0][0]
# __________________________________________________________________________________________________
# conc2d_14 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_13[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_14 (BatchNormalizatio (None, None, None, 2 1024        conc2d_14[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_14 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_14[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, None, None, 2 0           leakyrelu_idx_12[0][0]
#                                                                  leakyrelu_idx_14[0][0]
# __________________________________________________________________________________________________
# conc2d_15 (Conv2D)              (None, None, None, 1 32768       add_83[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_15 (BatchNormalizatio (None, None, None, 1 512         conc2d_15[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_15 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_15[0][0]
# __________________________________________________________________________________________________
# conc2d_16 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_15[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_16 (BatchNormalizatio (None, None, None, 2 1024        conc2d_16[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_16 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_16[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, None, None, 2 0           add_83[0][0]
#                                                                  leakyrelu_idx_16[0][0]
# __________________________________________________________________________________________________
# conc2d_18 (Conv2D)              (None, None, None, 1 32768       add_84[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_18 (BatchNormalizatio (None, None, None, 1 512         conc2d_18[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_18 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_18[0][0]
# __________________________________________________________________________________________________
# conc2d_19 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_18[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_19 (BatchNormalizatio (None, None, None, 2 1024        conc2d_19[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_19 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_19[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, None, None, 2 0           add_84[0][0]
#                                                                  leakyrelu_idx_19[0][0]
# __________________________________________________________________________________________________
# conc2d_21 (Conv2D)              (None, None, None, 1 32768       add_85[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_21 (BatchNormalizatio (None, None, None, 1 512         conc2d_21[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_21 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_21[0][0]
# __________________________________________________________________________________________________
# conc2d_22 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_21[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_22 (BatchNormalizatio (None, None, None, 2 1024        conc2d_22[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_22 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_22[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, None, None, 2 0           add_85[0][0]
#                                                                  leakyrelu_idx_22[0][0]
# __________________________________________________________________________________________________
# conc2d_24 (Conv2D)              (None, None, None, 1 32768       add_86[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_24 (BatchNormalizatio (None, None, None, 1 512         conc2d_24[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_24 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_24[0][0]
# __________________________________________________________________________________________________
# conc2d_25 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_24[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_25 (BatchNormalizatio (None, None, None, 2 1024        conc2d_25[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_25 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_25[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, None, None, 2 0           add_86[0][0]
#                                                                  leakyrelu_idx_25[0][0]
# __________________________________________________________________________________________________
# conc2d_27 (Conv2D)              (None, None, None, 1 32768       add_87[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_27 (BatchNormalizatio (None, None, None, 1 512         conc2d_27[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_27 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_27[0][0]
# __________________________________________________________________________________________________
# conc2d_28 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_27[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_28 (BatchNormalizatio (None, None, None, 2 1024        conc2d_28[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_28 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_28[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, None, None, 2 0           add_87[0][0]
#                                                                  leakyrelu_idx_28[0][0]
# __________________________________________________________________________________________________
# conc2d_30 (Conv2D)              (None, None, None, 1 32768       add_88[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_30 (BatchNormalizatio (None, None, None, 1 512         conc2d_30[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_30 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_30[0][0]
# __________________________________________________________________________________________________
# conc2d_31 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_30[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_31 (BatchNormalizatio (None, None, None, 2 1024        conc2d_31[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_31 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_31[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, None, None, 2 0           add_88[0][0]
#                                                                  leakyrelu_idx_31[0][0]
# __________________________________________________________________________________________________
# conc2d_33 (Conv2D)              (None, None, None, 1 32768       add_89[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_33 (BatchNormalizatio (None, None, None, 1 512         conc2d_33[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_33 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_33[0][0]
# __________________________________________________________________________________________________
# conc2d_34 (Conv2D)              (None, None, None, 2 294912      leakyrelu_idx_33[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_34 (BatchNormalizatio (None, None, None, 2 1024        conc2d_34[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_34 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_34[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, None, None, 2 0           add_89[0][0]
#                                                                  leakyrelu_idx_34[0][0]
# __________________________________________________________________________________________________
# zeropad_37 (ZeroPadding2D)      (None, None, None, 2 0           add_90[0][0]
# __________________________________________________________________________________________________
# conc2d_37 (Conv2D)              (None, None, None, 5 1179648     zeropad_37[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_37 (BatchNormalizatio (None, None, None, 5 2048        conc2d_37[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_37 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_37[0][0]
# __________________________________________________________________________________________________
# conc2d_38 (Conv2D)              (None, None, None, 2 131072      leakyrelu_idx_37[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_38 (BatchNormalizatio (None, None, None, 2 1024        conc2d_38[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_38 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_38[0][0]
# __________________________________________________________________________________________________
# conc2d_39 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_38[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_39 (BatchNormalizatio (None, None, None, 5 2048        conc2d_39[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_39 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_39[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, None, None, 5 0           leakyrelu_idx_37[0][0]
#                                                                  leakyrelu_idx_39[0][0]
# __________________________________________________________________________________________________
# conc2d_41 (Conv2D)              (None, None, None, 2 131072      add_91[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_41 (BatchNormalizatio (None, None, None, 2 1024        conc2d_41[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_41 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_41[0][0]
# __________________________________________________________________________________________________
# conc2d_42 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_41[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_42 (BatchNormalizatio (None, None, None, 5 2048        conc2d_42[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_42 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_42[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, None, None, 5 0           add_91[0][0]
#                                                                  leakyrelu_idx_42[0][0]
# __________________________________________________________________________________________________
# conc2d_44 (Conv2D)              (None, None, None, 2 131072      add_92[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_44 (BatchNormalizatio (None, None, None, 2 1024        conc2d_44[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_44 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_44[0][0]
# __________________________________________________________________________________________________
# conc2d_45 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_44[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_45 (BatchNormalizatio (None, None, None, 5 2048        conc2d_45[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_45 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_45[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, None, None, 5 0           add_92[0][0]
#                                                                  leakyrelu_idx_45[0][0]
# __________________________________________________________________________________________________
# conc2d_47 (Conv2D)              (None, None, None, 2 131072      add_93[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_47 (BatchNormalizatio (None, None, None, 2 1024        conc2d_47[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_47 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_47[0][0]
# __________________________________________________________________________________________________
# conc2d_48 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_47[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_48 (BatchNormalizatio (None, None, None, 5 2048        conc2d_48[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_48 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_48[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, None, None, 5 0           add_93[0][0]
#                                                                  leakyrelu_idx_48[0][0]
# __________________________________________________________________________________________________
# conc2d_50 (Conv2D)              (None, None, None, 2 131072      add_94[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_50 (BatchNormalizatio (None, None, None, 2 1024        conc2d_50[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_50 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_50[0][0]
# __________________________________________________________________________________________________
# conc2d_51 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_50[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_51 (BatchNormalizatio (None, None, None, 5 2048        conc2d_51[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_51 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_51[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, None, None, 5 0           add_94[0][0]
#                                                                  leakyrelu_idx_51[0][0]
# __________________________________________________________________________________________________
# conc2d_53 (Conv2D)              (None, None, None, 2 131072      add_95[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_53 (BatchNormalizatio (None, None, None, 2 1024        conc2d_53[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_53 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_53[0][0]
# __________________________________________________________________________________________________
# conc2d_54 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_53[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_54 (BatchNormalizatio (None, None, None, 5 2048        conc2d_54[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_54 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_54[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, None, None, 5 0           add_95[0][0]
#                                                                  leakyrelu_idx_54[0][0]
# __________________________________________________________________________________________________
# conc2d_56 (Conv2D)              (None, None, None, 2 131072      add_96[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_56 (BatchNormalizatio (None, None, None, 2 1024        conc2d_56[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_56 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_56[0][0]
# __________________________________________________________________________________________________
# conc2d_57 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_56[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_57 (BatchNormalizatio (None, None, None, 5 2048        conc2d_57[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_57 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_57[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, None, None, 5 0           add_96[0][0]
#                                                                  leakyrelu_idx_57[0][0]
# __________________________________________________________________________________________________
# conc2d_59 (Conv2D)              (None, None, None, 2 131072      add_97[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_59 (BatchNormalizatio (None, None, None, 2 1024        conc2d_59[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_59 (LeakyReLU)    (None, None, None, 2 0           bnorm_idx_59[0][0]
# __________________________________________________________________________________________________
# conc2d_60 (Conv2D)              (None, None, None, 5 1179648     leakyrelu_idx_59[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_60 (BatchNormalizatio (None, None, None, 5 2048        conc2d_60[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_60 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_60[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, None, None, 5 0           add_97[0][0]
#                                                                  leakyrelu_idx_60[0][0]
# __________________________________________________________________________________________________
# zeropad_62 (ZeroPadding2D)      (None, None, None, 5 0           add_98[0][0]
# __________________________________________________________________________________________________
# conc2d_62 (Conv2D)              (None, None, None, 1 4718592     zeropad_62[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_62 (BatchNormalizatio (None, None, None, 1 4096        conc2d_62[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_62 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_62[0][0]
# __________________________________________________________________________________________________
# conc2d_63 (Conv2D)              (None, None, None, 5 524288      leakyrelu_idx_62[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_63 (BatchNormalizatio (None, None, None, 5 2048        conc2d_63[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_63 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_63[0][0]
# __________________________________________________________________________________________________
# conc2d_64 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_63[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_64 (BatchNormalizatio (None, None, None, 1 4096        conc2d_64[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_64 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_64[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, None, None, 1 0           leakyrelu_idx_62[0][0]
#                                                                  leakyrelu_idx_64[0][0]
# __________________________________________________________________________________________________
# conc2d_66 (Conv2D)              (None, None, None, 5 524288      add_99[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_66 (BatchNormalizatio (None, None, None, 5 2048        conc2d_66[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_66 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_66[0][0]
# __________________________________________________________________________________________________
# conc2d_67 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_66[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_67 (BatchNormalizatio (None, None, None, 1 4096        conc2d_67[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_67 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_67[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, None, None, 1 0           add_99[0][0]
#                                                                  leakyrelu_idx_67[0][0]
# __________________________________________________________________________________________________
# conc2d_69 (Conv2D)              (None, None, None, 5 524288      add_100[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_69 (BatchNormalizatio (None, None, None, 5 2048        conc2d_69[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_69 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_69[0][0]
# __________________________________________________________________________________________________
# conc2d_70 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_69[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_70 (BatchNormalizatio (None, None, None, 1 4096        conc2d_70[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_70 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_70[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, None, None, 1 0           add_100[0][0]
#                                                                  leakyrelu_idx_70[0][0]
# __________________________________________________________________________________________________
# conc2d_72 (Conv2D)              (None, None, None, 5 524288      add_101[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_72 (BatchNormalizatio (None, None, None, 5 2048        conc2d_72[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_72 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_72[0][0]
# __________________________________________________________________________________________________
# conc2d_73 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_72[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_73 (BatchNormalizatio (None, None, None, 1 4096        conc2d_73[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_73 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_73[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, None, None, 1 0           add_101[0][0]
#                                                                  leakyrelu_idx_73[0][0]
# __________________________________________________________________________________________________
# conc2d_75 (Conv2D)              (None, None, None, 5 524288      add_102[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_75 (BatchNormalizatio (None, None, None, 5 2048        conc2d_75[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_75 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_75[0][0]
# __________________________________________________________________________________________________
# conc2d_76 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_75[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_76 (BatchNormalizatio (None, None, None, 1 4096        conc2d_76[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_76 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_76[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, None, None, 1 0           add_102[0][0]
#                                                                  leakyrelu_idx_76[0][0]
# __________________________________________________________________________________________________
# conc2d_78 (Conv2D)              (None, None, None, 5 524288      add_103[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_78 (BatchNormalizatio (None, None, None, 5 2048        conc2d_78[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_78 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_78[0][0]
# __________________________________________________________________________________________________
# conc2d_79 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_78[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_79 (BatchNormalizatio (None, None, None, 1 4096        conc2d_79[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_79 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_79[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, None, None, 1 0           add_103[0][0]
#                                                                  leakyrelu_idx_79[0][0]
# __________________________________________________________________________________________________
# conc2d_81 (Conv2D)              (None, None, None, 5 524288      add_104[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_81 (BatchNormalizatio (None, None, None, 5 2048        conc2d_81[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_81 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_81[0][0]
# __________________________________________________________________________________________________
# conc2d_82 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_81[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_82 (BatchNormalizatio (None, None, None, 1 4096        conc2d_82[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_82 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_82[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, None, None, 1 0           add_104[0][0]
#                                                                  leakyrelu_idx_82[0][0]
# __________________________________________________________________________________________________
# conc2d_84 (Conv2D)              (None, None, None, 5 524288      add_105[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_84 (BatchNormalizatio (None, None, None, 5 2048        conc2d_84[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_84 (LeakyReLU)    (None, None, None, 5 0           bnorm_idx_84[0][0]
# __________________________________________________________________________________________________
# conc2d_85 (Conv2D)              (None, None, None, 1 4718592     leakyrelu_idx_84[0][0]
# __________________________________________________________________________________________________
# bnorm_idx_85 (BatchNormalizatio (None, None, None, 1 4096        conc2d_85[0][0]
# __________________________________________________________________________________________________
# leakyrelu_idx_85 (LeakyReLU)    (None, None, None, 1 0           bnorm_idx_85[0][0]
# __________________________________________________________________________________________________
# add_106 (Add)                   (None, None, None, 1 0           add_105[0][0]
#                                                                  leakyrelu_idx_85[0][0]
# ==================================================================================================
# Total params: 61,616,736
# Trainable params: 61,568,736
# Non-trainable params: 48,000
# __________________________________________________________________________________________________
